# %% [markdown]
# ECE 447: Root Locus Design
# ===
#
# Prof. Eric Klavins
#
# &copy; 2019, University of Washington

# %% [markdown]
# # Code

# %%
import numpy as np
import scipy.integrate as spi
import matplotlib.pyplot as plt
from sympy import *
from control import *

# %matplotlib inline

# Comment out in Google colab 
init_printing(use_latex='mathjax')

# Uncomment in below Google colab to render sympy equations nicely
# def custom_latex_printer(exp,**options):
#     from google.colab.output._publish import javascript
#     url = "https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default"
#     javascript(url=url)
#     return printing.latex(exp,**options)
# init_printing(use_latex="mathjax",latex_printer=custom_latex_printer)

# %% [markdown]
# # Goal

# %% [markdown]
# The goal with root locus based design is to design a controller $G_c(s)$ to alter the shape of the root locus so that a gain $K$ can be chosen to give the desired performance. In the diagram below, the system with $KG(s)$ has marginally stable poles no matter what $K$ you choose. By adding a zero and remembering that the root locus goes from the poles to the zeros, we get as root locus for $KG_c(s)G(s)$ that can contains a variety of stable poles for different values of the gain $K$.
#
# <img width=55% src="https://raw.githubusercontent.com/klavins/ECE447/master/images/root-locus-design.png">

# %% [markdown]
# # Examples

# %% [markdown]
# Example: PI Control
# ---
#
# A Proportional-Integral controller has the form
#
# $$
# G_c(s) = \frac{K_I}{s} + K_p
# $$
#
# which can be rewritten
#
# $$
# G_c(s) = \frac{K_p\left(s+\frac{K_I}{K_p}\right)}{s}
# $$
#
# Thus, PI control is adding a new pole at 0 and a new zero at $-\frac{K_I}{K_p}$.
#
# Example: PI Control of a Simple System
# ---
#
# Suppose $G(s) = \frac{1}{s}$
#
# <img width=55% src="https://raw.githubusercontent.com/klavins/ECE447/master/images/root-locus-pi.png">

# %%
# Simple control: Only totally damped response possible
sys1 = tf([1],[1,0])
r,k = root_locus(sys1,xlim=(-2,1))

# %%
# PI control: A range of gains possible
z = -1
sys1 = tf([1,-z],[1,0,0])
r,k = root_locus(sys1,xlim=(-3,1))

# %% [markdown]
# Example: PID Control
# ---
#
# A Proportional-Integral-Derivative controller has the form
#
# $$
# G_c(s) = K_p + K_D s + \frac{K_I}{s}
# $$
#
# which can be written
#
# \begin{align}
# G_c(s) & = \frac{K_D s^2 + K_p s + K_I}{s^2} \\
#        & = K_d \frac{(p+z_1)(p+z_2)}{s^2}
# \end{align}
#
# Therefore, a PID controller amounts to picking two zero locations and placing to poles at zero.

# %% [markdown]
# Example: PID Design
# ---
#
# Suppose we wish to control the system
#
# $$
# G(s) = \frac{1}{s^2+2s+2}
# $$
#
# which has poles at $-1 \pm i$. Without a controller, the root locus looks like the following:

# %%
# Gain only, no controller
sys1 = tf([1],[1,2,2])
r,k = root_locus(sys1,xlim=(-3,1))

# %% [markdown]
# Now say we want the system to have a settling time of four seconds and a 10% overshoot. Then
#
# $$
# \zeta\omega = 4
# $$
#
# and
#
# $$
# \frac{\zeta\pi}{\beta} = - \ln (0.1)
# $$
#
# Solving the above gives:

# %%
var("s zeta omega")
sol=solve([zeta*omega-4, zeta*pi/sqrt(1-zeta**2)-log(0.1)])[0]
sol
# Out:
# {ω: -6.76641451278031, ζ: -0.591155033798898}

# %% [markdown]
# Putting these values into
#
# $$
# s^2 + 2 \zeta \omega s + \omega^2
# $$
#
# and solving for $s$ gives us the desired denominator of $T(s):

# %%
den = (s**2 + 2*zeta*omega*s + omega**2).subs(sol)
den
# Out:
#  2
# s  + 8.0⋅s + 45.784365358764

# %% [markdown]
# That is, we want to place the poles of $T(s)$ at

# %%
den = (s**2 + 2*zeta*omega*s + omega**2).subs(sol)
poles = solve(den,s)
poles
# Out:
# [-4.0 - 5.45750541536735⋅ⅈ, -4.0 + 5.45750541536735⋅ⅈ]

# %% [markdown]
# We can't place the poles anywhere, but we do know that as $K$ goes to $\infty$, the root locus goes to the zeros. So we can define a PID controller by
#
# $$
# K_D \frac{s^2 + 2 \zeta \omega s + \omega^2}{s}
# $$
#
# or in this case

# %%
Gc = den / s
Gc
# Out:
# ⎛  ⎛    ⎛  ⎛ 2                          ⎞    ⎞    ⎞    ⎞
# ⎜  ⎜    ⎜K⋅⎝s  + 8.0⋅s + 45.784365358764⎠    ⎟    ⎟    ⎟
# ⎜K⋅⎜K⋅s⋅⎜──────────────────────────────── + 1⎟ + 1⎟    ⎟
# ⎜  ⎜    ⎜          ⎛ 2          ⎞            ⎟    ⎟    ⎟
# ⎜  ⎝    ⎝        s⋅⎝s  + 2⋅s + 2⎠            ⎠    ⎠    ⎟ ⎛ 2          ⎞
# ⎜────────────────────────────────────────────────── + 1⎟⋅⎝s  + 2⋅s + 2⎠
# ⎜                   ⎛ 2          ⎞                     ⎟
# ⎝                 s⋅⎝s  + 2⋅s + 2⎠                     ⎠

# %%
G = 1 / ( s**2 + 2*s + 2 )
GcG = Gc*G
GcG.cancel()
# Out:
#     ⎛     3  2        3                      3        2  3        2  2
# 1.0⋅⎝1.0⋅K ⋅s  + 8.0⋅K ⋅s + 45.784365358764⋅K  + 1.0⋅K ⋅s  + 2.0⋅K ⋅s  + 2.0⋅K
# ──────────────────────────────────────────────────────────────────────────────
#                                                               5        4
#                                                          1.0⋅s  + 4.0⋅s  + 8.0
#
# 2            2                          5        4        3        2        ⎞
#  ⋅s + 1.0⋅K⋅s  + 2.0⋅K⋅s + 2.0⋅K + 1.0⋅s  + 4.0⋅s  + 8.0⋅s  + 8.0⋅s  + 4.0⋅s⎠
# ─────────────────────────────────────────────────────────────────────────────
#   3        2
# ⋅s  + 8.0⋅s  + 4.0⋅s

# %%
var("K")
T = K * Gc * G / ( 1 + K * Gc * G)
T.cancel()
num,den=fraction(T)
solve(den.subs(K,100))
# Out:
# ------------------------------------------------------------------
# KeyError                         Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1276     try:
# -> 1277         rf = evalf_table[x.func]
#    1278         r = rf(x, prec, options)
#
# KeyError: <class 'sympy.polys.rootoftools.ComplexRootOf'>
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-196-0a71f6de0684> in <module>()
#       3 T.cancel()
#       4 num,den=fraction(T)
# ----> 5 solve(den.subs(K,100))
#
# /anaconda/lib/python3.6/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1051     ###########################################################################
#    1052     if bare_f:
# -> 1053         solution = _solve(f[0], *symbols, **flags)
#    1054     else:
#    1055         solution = _solve_system(f, symbols, **flags)
#
# /anaconda/lib/python3.6/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1629         # if in doubt, keep it
#    1630         dens = _simple_dens(f, symbols)
# -> 1631         result = [s for s in result if
#    1632                   all(not checksol(d, {symbol: s}, **flags)
#    1633                     for d in dens)]
#
# /anaconda/lib/python3.6/site-packages/sympy/solvers/solvers.py in <listcomp>(.0)
#    1631         result = [s for s in result if
#    1632                   all(not checksol(d, {symbol: s}, **flags)
# -> 1633                     for d in dens)]
#    1634     if check:
#    1635         # keep only results if the check is not False
#
# /anaconda/lib/python3.6/site-packages/sympy/solvers/solvers.py in <genexpr>(.0)
#    1631         result = [s for s in result if
#    1632                   all(not checksol(d, {symbol: s}, **flags)
# -> 1633                     for d in dens)]
#    1634     if check:
#    1635         # keep only results if the check is not False
#
# /anaconda/lib/python3.6/site-packages/sympy/solvers/solvers.py in checksol(f, symbol, sol, **flags)
#     301             return val == 0
#     302         if numerical and not val.free_symbols:
# --> 303             return bool(abs(val.n(18).n(12, chop=True)) < 1e-9)
#     304         was = val
#     305
#
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1383             options['quad'] = quad
#    1384         try:
# -> 1385             result = evalf(self, prec + 4, options)
#    1386         except NotImplementedError:
#    1387             # Fall back to the ordinary evalf
#
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1276     try:
#    1277         rf = evalf_table[x.func]
# -> 1278         r = rf(x, prec, options)
#    1279     except KeyError:
#    1280         try:
#
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in evalf_add(v, prec, options)
#     488         options['maxprec'] = min(oldmaxprec, 2*prec)
#     489
# --> 490         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     491         re, re_acc = add_terms(
#     492             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in <listcomp>(.0)
#     488         options['maxprec'] = min(oldmaxprec, 2*prec)
#     489
# --> 490         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     491         re, re_acc = add_terms(
#     492             [a[0::2] for a in terms if a[0]], prec, target_prec)
#
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1276     try:
#    1277         rf = evalf_table[x.func]
# -> 1278         r = rf(x, prec, options)
#    1279     except KeyError:
#    1280         try:
#
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in evalf_mul(v, prec, options)
#     566         elif i == last and arg is S.One:
#     567             continue
# --> 568         re, im, re_acc, im_acc = evalf(arg, working_prec, options)
#     569         if re and im:
#     570             complex_factors.append((re, im, re_acc, im_acc))
#
# /anaconda/lib/python3.6/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1282             if 'subs' in options:
#    1283                 x = x.subs(evalf_subs(prec, options['subs']))
# -> 1284             re, im = x._eval_evalf(prec).as_real_imag()
#    1285             if re.has(re_) or im.has(im_):
#    1286                 raise NotImplementedError
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/rootoftools.py in _eval_evalf(self, prec)
#     611                 by = interval.by
#     612                 while interval.ay == ay or interval.by == by:
# --> 613                     interval = interval.refine()
#     614
#     615             while True:
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/rootisolation.py in refine(self)
#    1900     def refine(self):
#    1901         """Perform one step of complex root refinement algorithm. """
# -> 1902         return self._inner_refine()
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/rootisolation.py in _inner_refine(self)
#    1856
#    1857         if s - u > t - v:
# -> 1858             D_L, D_R = _vertical_bisection(1, (u, v), (s, t), I, Q, F1, F2, f1, f2, dom)
#    1859
#    1860             if D_L[0] == 1:
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/rootisolation.py in _vertical_bisection(N, a, b, I, Q, F1, F2, f1, f2, F)
#    1342     Q_L1_L = _intervals_to_quadrants(I_L1_L, f1L1F, f2L1F, u, x, F)
#    1343     Q_L2_L = _intervals_to_quadrants(I_L2_L, f1V, f2V, v, t, F)
# -> 1344     Q_L3_L = _intervals_to_quadrants(I_L3_L, f1L3F, f2L3F, x, u, F)
#    1345     Q_L4_L = Q_L4
#    1346
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/rootisolation.py in _intervals_to_quadrants(intervals, f1, f2, s, t, F)
#    1053         return Q
#    1054
# -> 1055     re = dup_eval(f1, s, F)
#    1056     im = dup_eval(f2, s, F)
#    1057
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/densetools.py in dup_eval(f, a, K)
#     286     for c in f:
#     287         result *= a
# --> 288         result += c
#     289
#     290     return result
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/domains/pythonrational.py in __add__(self, other)
#     109             return NotImplemented
#     110
# --> 111         return self.__class__(p, q)
#     112
#     113     def __radd__(self, other):
#
# /anaconda/lib/python3.6/site-packages/sympy/polys/domains/pythonrational.py in __init__(self, p, q)
#      59
#      60             while y:
# ---> 61                 x, y = y, x % y
#      62
#      63             if x != 1:
#
# KeyboardInterrupt:

# %%
sys = tf([1,8,45.78],[1,2,2,0])
r,k=root_locus(sys,xlim=(-5,1))

# %%
gain = tf([50],[1])
fb = feedback(series(sys,gain))
t,y = step_response(fb)
plt.plot(t,y);

# %% [markdown]
# # PID Control One Component at a Time

# %%
# Example Plant
G = (s+3) / ((s+1)*(s+2))
G.cancel()
# Out:
#    s + 3
# ────────────
#  2
# s  + 3⋅s + 2

# %%
# Proportional Control
Gc = 1
(Gc*G).cancel()
# Out:
#    s + 3
# ────────────
#  2
# s  + 3⋅s + 2

# %%
# Proportional Control Root Locus
# Good, but may not be able to get a desired percent overshoot
sys = tf([1,3],[1,3,2])
r,k=root_locus(sys,xlim=(-5,1))

# %%
# Derivative control
Gc = s
(Gc*G).cancel()
# Out:
#    2
#   s  + 3⋅s
# ────────────
#  2
# s  + 3⋅s + 2

# %%
# Derivative Control Root Locus
# No way to get overshoot at all
sys = tf([1,3,0],[1,3,2])
r,k=root_locus(sys,xlim=(-5,1))

# %%
# Integral control
Gc = 1/s
(Gc*G).cancel()
# Out:
#      s + 3
# ───────────────
#  3      2
# s  + 3⋅s  + 2⋅s

# %%
# Integral Control Root Locus
# R.L is too close to imaginary axis for comfort
sys = tf([1,3],[1,3,2,0])
r,k=root_locus(sys,xlim=(-5,1))

# %%
# PID control
Gc = 10 + s + 26/s
(Gc*G).cancel()
# Out:
#  3       2
# s  + 13⋅s  + 56⋅s + 78
# ──────────────────────
#     3      2
#    s  + 3⋅s  + 2⋅s

# %%
# PID Control Root Locus
# R.L in region with good percent overshoot
sys = tf([1,13,56,78],[1,3,2,0])
r,k=root_locus(sys,xlim=(-5,1))

# %% [markdown]
# # Don't cancel poles and zeros

# %% [markdown]
# Suppose that
#
# $$
# G(s) = \frac{1}{s^2+1}
# $$
#
# which has poles at $\pm i$. To stabilize this system, you might be tempted to put
#
# $$
# K G_c(s) = K \frac{s^2+1}{s}
# $$
#
# so that
#
# $$
# K Gc(s) G(s) = \frac{K}{s}.
# $$
#
# This system looks great since you can get any negative real pole you want along the root locus.
#
# However, because $G(s)$ is just a model and possibly inaccurate, you probably would get a root locus more like the following, which is not very stable or even possibly unstable.

# %%
G = 1 / ( s**2 - 0.1*s + 1.1) # what you might actually get instead of 
                              # 1 / ( s**2 + 1 )
Gc = (s**2 + 1)/s
Gc*G
# Out:
#         2
#        s  + 1
# ────────────────────
#   ⎛ 2              ⎞
# s⋅⎝s  - 0.1⋅s + 1.1⎠

# %%
sys = tf([1,0,1],[1,-0.1,1.1,0])
r,k=root_locus(sys,xlim=(-1,1))
